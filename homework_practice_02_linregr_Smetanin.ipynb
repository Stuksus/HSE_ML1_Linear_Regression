# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Предисловие" data-toc-modified-id="Предисловие-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Предисловие</a></span></li><li><span><a href="#Машинное-обучение,-ФКН-ВШЭ" data-toc-modified-id="Машинное-обучение,-ФКН-ВШЭ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Машинное обучение, ФКН ВШЭ</a></span><ul class="toc-item"><li><span><a href="#Практическое-задание-2.-Exploratory-Data-Analysis-и-линейная-регрессия" data-toc-modified-id="Практическое-задание-2.-Exploratory-Data-Analysis-и-линейная-регрессия-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Практическое задание 2. Exploratory Data Analysis и линейная регрессия</a></span><ul class="toc-item"><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#О-задании" data-toc-modified-id="О-задании-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>О задании</a></span></li><li><span><a href="#Оценивание-и-штрафы" data-toc-modified-id="Оценивание-и-штрафы-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Оценивание и штрафы</a></span></li><li><span><a href="#Формат-сдачи" data-toc-modified-id="Формат-сдачи-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Формат сдачи</a></span></li></ul></li><li><span><a href="#Часть-0.-Подготовка-(1-балл)" data-toc-modified-id="Часть-0.-Подготовка-(1-балл)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Часть 0. Подготовка (1 балл)</a></span><ul class="toc-item"><li><span><a href="#Data-fields" data-toc-modified-id="Data-fields-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Data fields</a></span></li></ul></li><li><span><a href="#Часть-1.-Изучаем-pickup_datetime-(2-балла)" data-toc-modified-id="Часть-1.-Изучаем-pickup_datetime-(2-балла)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Часть 1. Изучаем <code>pickup_datetime</code> (2 балла)</a></span></li><li><span><a href="#Часть-2.-Изучаем-координаты-(3-балла)" data-toc-modified-id="Часть-2.-Изучаем-координаты-(3-балла)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Часть 2. Изучаем координаты (3 балла)</a></span></li><li><span><a href="#Часть-3.-Изучаем-оставшиеся-признаки-(1-балл)" data-toc-modified-id="Часть-3.-Изучаем-оставшиеся-признаки-(1-балл)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Часть 3. Изучаем оставшиеся признаки (1 балл)</a></span></li><li><span><a href="#Часть-4.-Улучшаем-модель-(3-балла)" data-toc-modified-id="Часть-4.-Улучшаем-модель-(3-балла)-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Часть 4. Улучшаем модель (3 балла)</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Машинное обучение, ФКН ВШЭ
#
# ## Практическое задание 2. Exploratory Data Analysis и линейная регрессия
#
# ### Общая информация
# Дата выдачи: 26.09.2021
#
# Мягкий дедлайн: 23:59MSK 11.10.2021
#
# Жесткий дедлайн: 23:59MSK 14.10.2021

# %% [markdown]
# ### О задании
# В этом задании мы попытаемся научиться анализировать данные и выделять из них полезные признаки. Мы также научимся пользоваться `seaborn` и `sklearn`, а заодно привыкнем к основным понятиям машинного обучения.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов. Проверяющий имеет право снизить оценку за неэффективную реализацию или неопрятные графики.
#
# **Обратите внимание**, что в каждом разделе домашнего задания есть оцениваниемые задачи и есть вопросы. Вопросы дополняют задачи и направлены на то, чтобы проинтерпретировать или обосновать происходящее. Код без интерпретации не имеет смысла, поэтому отвечать на вопросы обязательно — за отсутствие ответов мы будем снижать баллы за задачи. Если вы ответите на вопросы, но не напишете корректный код к соответствующим оцениваемым задачам, то баллы за такое выставлены не будут.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно найти на странице курса. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-02-linregr-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: 10.

# %% [markdown]
# В этом ноутбуке используется библиотека `folium` для визуализации карт. Она работает в google colab!

# %%
# !pip install folium

# %%
import folium

m = folium.Map(location=(55.7522200, 37.6155600), zoom_start=10)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Если вы всё сделали правильно, то выше должна открыться карта Москвы.

# %%
# !pip install haversine

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from haversine import haversine, Unit
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# %matplotlib inline
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
plt.rcParams['savefig.format'] = 'pdf'
sns.set(style="darkgrid")

# %% [markdown]
# ## Часть 0. Подготовка (1 балл)

# %% [markdown]
# **Задание 1 (1 балл)**. Мы будем работать с данными из соревнования [New York City Taxi Trip Duration](https://www.kaggle.com/c/nyc-taxi-trip-duration/overview), в котором нужно было предсказать длительность поездки на такси. Скачайте обучающую выборку из этого соревнования и загрузите ее:

# %% [markdown]
# ### Data fields
#
# - id - a unique identifier for each trip
# - vendor_id - a code indicating the provider associated with the trip record
# - pickup_datetime - date and time when the meter was engaged
# - dropoff_datetime - date and time when the meter was disengaged
# - passenger_count - the number of passengers in the vehicle (driver entered value)
# - pickup_longitude - the longitude where the meter was engaged
# - pickup_latitude - the latitude where the meter was engaged
# - dropoff_longitude - the longitude where the meter was disengaged
# - dropoff_latitude - the latitude where the meter was disengaged
# - store_and_fwd_flag - This flag indicates whether the trip record was held in vehicle memory before sending to the vendor because the vehicle did not have a connection to the server - Y=store and forward; N=not a store and forward trip
# - trip_duration - duration of the trip in seconds

# %%
frame = pd.read_csv('train.csv')

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  object
#  3   dropoff_datetime    1458644 non-null  object
#  4   passenger_count     1458644 non-null  int64
#  5   pickup_longitude    1458644 non-null  float64
#  6   pickup_latitude     1458644 non-null  float64
#  7   dropoff_longitude   1458644 non-null  float64
#  8   dropoff_latitude    1458644 non-null  float64
#  9   store_and_fwd_flag  1458644 non-null  object
#  10  trip_duration       1458644 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %%
frame.describe().round(2)
# Out:
#         vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  1458644.00       1458644.00        1458644.00       1458644.00
# mean         1.53             1.66            -73.97            40.75
# std          0.50             1.31              0.07             0.03
# min          1.00             0.00           -121.93            34.36
# 25%          1.00             1.00            -73.99            40.74
# 50%          2.00             1.00            -73.98            40.75
# 75%          2.00             2.00            -73.97            40.77
# max          2.00             9.00            -61.34            51.88
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count         1458644.00        1458644.00     1458644.00
# mean              -73.97             40.75         959.49
# std                 0.07              0.04        5237.43
# min              -121.93             32.18           1.00
# ...

# %%
frame.sample(20)
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 480300   id0081824          1  2016-01-05 00:52:16  2016-01-05 01:00:54
# 734269   id1726232          2  2016-01-19 14:21:58  2016-01-19 14:33:54
# 464373   id2104822          2  2016-02-23 17:07:02  2016-02-23 17:38:22
# 663102   id0679579          1  2016-03-02 12:18:49  2016-03-02 12:47:54
# 118844   id3690358          1  2016-02-18 11:05:05  2016-02-18 11:21:11
# 638151   id2000537          2  2016-02-13 13:17:58  2016-02-13 13:23:54
# 1142097  id0316133          2  2016-02-25 08:09:40  2016-02-25 08:30:31
# 673785   id2645573          2  2016-05-25 06:48:38  2016-05-25 06:57:24
# 899254   id3928712          1  2016-04-29 15:36:24  2016-04-29 15:48:26
# 750395   id3211218          1  2016-01-29 23:40:33  2016-01-29 23:49:45
# 94640    id1146730          1  2016-04-17 17:15:54  2016-04-17 18:16:51
# 1233186  id3675286          1  2016-05-18 21:29:51  2016-05-18 21:52:08
# ...

# %% [markdown]
# Обратите внимание на колонки `pickup_datetime` и `dropoff_datetime`. `dropoff_datetime` был добавлена организаторами только в обучающую выборку, то есть использовать эту колонку нельзя, давайте удалим ее. В `pickup_datetime` записаны дата и время начала поездки. Чтобы с ней было удобно работать, давайте преобразуем даты в `datetime`-объекты

# %% [markdown]
# 1) Удалим признак <code>dropoff_datetime</code>

# %%
frame = frame.drop('dropoff_datetime',axis = 1)

# %% [markdown]
# Проверим, что столбец удален успешно

# %%
print(f'В таблице есть dropoff_datetime: {"dropoff_datetime" in frame.columns}')
# Out:
# В таблице есть dropoff_datetime: False

# %% [markdown]
# 2) Приведем значение <code>pickup_datetime</code> к <code>datetime</code>

# %%
frame['pickup_datetime'] = pd.to_datetime(frame['pickup_datetime'])

# %% [markdown]
# Проверим, что тип привелся без ошибок

# %%
frame.dtypes
# Out:
# id                            object
# vendor_id                      int64
# pickup_datetime       datetime64[ns]
# passenger_count                int64
# pickup_longitude             float64
# pickup_latitude              float64
# dropoff_longitude            float64
# dropoff_latitude             float64
# store_and_fwd_flag            object
# trip_duration                  int64
# dtype: object

# %% [markdown]
# Все отлично!!

# %% [markdown]
# В колонке `trip_duration` записано целевое значение, которое мы хотим предсказывать. Давайте посмотрим на распределение таргета в обучающей выборке. Для этого нарисуйте его гистограмму:

# %%
plt.hist(frame['trip_duration'])
plt.xlabel('Продолжительность поездки')
plt.ylabel('Количество объектов')
plt.title('Распределение trip_duration');

# %% [markdown]
# **Вопрос**: Что можно сказать о целевой переменной по гистограмме её значений?

# %% [markdown]
# Как мы можем увидеть из гистограммы, у нас есть аномалии в значениях, которые образуют очень тяжелый правый хвост. Выше я вызывал функцию <code>describe()</code>, которая показала, что 75% значений меньше 1075 минут, а максимальное значение 3526282 минут, что порядка 6.7 лет. Это значение не может встретится в работе таксиста и скорее всего появилось в связи со сбоем при передаче данных или при их заполнении.

# %% [markdown]
# В соревновании в качестве метрики качества использовалось RMSLE:
# $$\text{RMSLE}(X, y, a) = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\log{(y_i + 1)} - \log{(a(x_i) + 1)}\big)^2}$$
#
# **Вопрос**: Как вы думаете, почему авторы соревнования выбрали именно RMSLE, а не RMSE?

# %% [markdown]
# Одной из причин, по которой была выбрана данная метрика является устойчивость к выбросам. Так как логарифмическая функция увеличивается относительно медленно при увеличении, переданного параметра, то и значение метрики не будет резко изменяться из-за попавшего выброса или аномалии. Так же из за природы целевой метрики, у нас всегда будет достаточно ощутимый правый хвост(не такой большой как сейчас, но даже после обработки хвост будет наблюдаться), поэтому здесь опять же очень полезен логарифм, который сгладит эту особенность

# %% [markdown]
# На семинаре мы рассматривали несколько моделей линейной регрессии в `sklearn`, но каждая из них оптимизировала среднеквадратичную ошибку (MSE), а не RMSLE. Давайте проделаем следующий трюк: будем предсказывать не целевую переменную, а ее *логарифм*. Обозначим $\hat{y}_i = \log{(y_i + 1)}$ — модифицированный таргет, а $\hat{a}(x_i)$ — предсказание модели, которая обучалась на $\hat{y}_i$, то есть логарифм таргета. Чтобы предсказать исходное значение, мы можем просто взять экспоненту от нашего предсказания: $a(x_i) = \exp(\hat{a}(x_i)) - 1$.
#
# **Вопрос**: Покажите, что оптимизация RMSLE для модели $a$ эквивалентна оптимизации MSE для модели $\hat{a}$.
#
# **Доказательство**:
# - $ MSE(\hat{y}_i,\hat{a},x_i): \frac{1}{n} \sum_{l}^{i=1}(\hat{y}_i - \hat{a}(x_i))^{2}$
# - $\hat{y}_i = \log{(y_i + 1)}$
# - $a(x_i) = \exp(\hat{a}(x_i)) - 1 => \hat{a}(x_i) = \log{(a(x_i)+ 1)}$
#
# Значит, если подставить все в одну формулу, получится:
#
# -  $MSE(y_i,a,x_i):\frac{1}{n} \sum_{l}^{i=1}(\log{(y_i + 1)} - \log{(a(x_i)+ 1)})^{2}$
#
# В то время как RMSLE равен:
#
# -   $RMSLE(y_i,a,x_i): \sqrt{\frac{1}{n} \sum_{l}^{i=1}(\log{(y_i + 1)} - \log{(a(x_i)+ 1)})^{2}}$
#
# Поскольку $g(x) \textbf{ ~ } \sqrt{g(x)}$
# Так как
# $g(x) = \sqrt{g(x)} + O(\sqrt{g(x)})$
#
# Как итог:
#
# $\sqrt{MSE(\hat{y}_i,\hat{a},x_i)} \textbf{ ~ } RMSLE(y_i,a,x_i)$
#
# Откуда в свою очередь следует следующее:
#
# $MSE(\hat{y}_i,\hat{a},x_i) \textbf{ ~ } RMSLE(y_i,a,x_i)$
#
# Итак, мы смогли свести задачу оптимизации RMSLE к задаче оптимизации MSE, которую мы умеем решать! Кроме того, у логарифмирования таргета есть еще одно полезное свойство. Чтобы его увидеть, добавьте к нашей выборке колонку `log_trip_duration` (воспользуйтесь `np.log1p`) и нарисуйте гистограмму модифицированного таргета по обучающей выборке. Удалите колонку со старым таргетом.

# %%
frame['log_trip_duration'] = np.log1p(frame['trip_duration'])
frame = frame.drop('trip_duration',axis = 1)

# %%
plt.hist(frame['log_trip_duration'])
plt.xlabel('Логорифмированная продолжительность поездки')
plt.ylabel('Количество объектов')
plt.title('Распределение trip_duration');

# %% [markdown]
# Чтобы иметь некоторую точку отсчета, давайте посчитаем значение метрики при наилучшем константном предсказании:

# %% [markdown]
# Сначала разберемся с категориальными признаками

# %%
# Переведем id  в index
frame_dummy = frame.set_index('id')
# Получим список всех категориальных признаков
get_cat_columns = frame_dummy.loc[:,frame_dummy.dtypes == np.dtype('object')].columns
print(f'Категориальные признаки: {get_cat_columns.values[0]}')
# Out:
# Категориальные признаки: store_and_fwd_flag

# %%
#Закодируем при помощи OHE признак и присоединим его к таблице
frame_dummy = frame_dummy.merge(pd.get_dummies(frame_dummy.loc[:,get_cat_columns]),
                                left_index=True,
                                right_index=True)
# Удалим изначальный категориальный признак
frame_dummy = frame_dummy.drop(get_cat_columns,axis = 1)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 10 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  datetime64[ns]
#  3   passenger_count     1458644 non-null  int64
#  4   pickup_longitude    1458644 non-null  float64
#  5   pickup_latitude     1458644 non-null  float64
#  6   dropoff_longitude   1458644 non-null  float64
#  7   dropoff_latitude    1458644 non-null  float64
#  8   store_and_fwd_flag  1458644 non-null  object
#  9   log_trip_duration   1458644 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(2)
# memory usage: 111.3+ MB

# %%
# Разделим выборку на трейн и тест, чтобы предсказать по среднему
(X_train_dummy,
 X_test_dummy,
 y_train_dummy,
 y_test_dummy) = train_test_split(frame_dummy.drop('log_trip_duration',axis = 1),
                                  frame_dummy['log_trip_duration'],test_size = 0.2,
                                  random_state = 42)

# %%
# Выберем стратегию среднего и обучим наш константный регрессор
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(X_train_dummy, y_train_dummy)
# Out:
# DummyRegressor()

# %%
# Сделаем предсказания
preds_dummy = dummy_regr.predict(X_test_dummy)
# Посчитаем метрику
rmsle_score_dummy = mean_squared_error(y_test_dummy,preds_dummy)
print('RMSLE на константной модели равен:', rmsle_score_dummy.round(4))
# Out:
# RMSLE на константной модели равен: 0.6346

# %% [markdown]
# ## Часть 1. Изучаем `pickup_datetime` (2 балла)
#
# **Задание 2 (0.25 баллов)**. Для начала давайте посмотрим, сколько всего было поездок в каждый из дней. Постройте график зависимости количества поездок от дня в году (например, можно воспользоваться `sns.countplot`):

# %%
# Aгрегируем даты по дню и посчитаем поличество поездок по id
day_ride = frame.set_index('pickup_datetime').resample('1D').count()['id']

# %%
fig,ax = plt.subplots(figsize = (38,5))
ax.bar(day_ride.index.astype('str'), day_ride,width=1)
plt.xlabel('Дата',fontsize = 14)
plt.ylabel('Количество поездок',fontsize = 14)
plt.title('Распределение количества поездок по дням',fontsize = 15)
plt.xticks(rotation=90);

# %% [markdown]
# **Вопрос**: Вы, вероятно, заметили, что на графике есть 2 периода с аномально маленькими количествами поездок. Вычислите, в какие даты происходили эти скачки вниз и найдите информацию о том, что происходило в эти дни в Нью-Йорке.
#
# Нарисуйте графики зависимости количества поездок от дня недели и от часов в сутках (воспользуйтесь `sns.relplot`):

# %% [markdown]
# Как можно видеть, на графике два сильных падения: с 23 по 26 февраля и в конце мая.
# Скорее всего данные падения связаны с праздниками.
# - 30 мая празднуется день поминовения, в который принято проводить время с семьей, что в свою очередь уменьшает кол-во заказов такси.
# - А в 22-23 (зависит от дня недели) празднуется президентский день

# %%
# Агрегируем поездки по часам
day_ride_by_hours = frame.set_index('pickup_datetime').resample('1H').count()['id'].reset_index()
# Добавляем новый признак: название дня недели
day_ride_by_hours['day_name'] = day_ride_by_hours['pickup_datetime'].dt.day_name()
# Добавляем новый признак: час в сутках
day_ride_by_hours['hours_number'] = day_ride_by_hours['pickup_datetime'].dt.hour
# Добавляем новый признак: номер месяца (для следующего задания)
day_ride_by_hours['month_name'] = day_ride_by_hours['pickup_datetime'].dt.month_name()
# Уберем не нужную информацию в индекс
day_ride_by_hours = day_ride_by_hours.set_index('pickup_datetime')

# %%
# Построим график 1
for_first_graph = day_ride_by_hours.groupby(['hours_number']).sum().reset_index()[['hours_number','id']]
g = sns.relplot(data=for_first_graph, y='id', x = "hours_number",kind="line",height=8, aspect=20/8)
g.set(xticks=range(24))
plt.title('Зависимость количества поездок от часов в сутках',fontsize = 14)
g.set_xlabels('Номер часа в сутках',fontsize = 13)
g.set_ylabels('Количесвто поездок',fontsize = 13);
# Построим график 2
for_second_graph = day_ride_by_hours.groupby(['day_name']).sum().reset_index()[['day_name','id']]
g2 = sns.relplot(data=for_second_graph, y='id', x = "day_name",kind="line",height=8, aspect=20/8)
plt.title('Зависимость количества поездок от дня недели',fontsize = 14)
g2.set_xlabels('День недели',fontsize = 13)
g2.set_ylabels('Количесвто поездок',fontsize = 13);

# %% [markdown]
# **Задание 3 (0.5 баллов)**. Нарисуйте на одном графике зависимости количества поездок от часа в сутках для разных месяцев (разные кривые, соответствующие разным месяцам, окрашивайте в разные цвета, воспользуйтесь `hue` в `sns.relplot`). Аналогично нарисуйте зависимости количества поездок от часа в сутках для разных дней недели.

# %%
# Построим график 3
for_third_graph = day_ride_by_hours.groupby(['month_name','hours_number']).sum().reset_index()[['month_name','hours_number','id']]
g3 = sns.relplot(data=for_third_graph, y='id', x = "hours_number",hue = 'month_name',kind="line",height=8, aspect=20/8)
g3.set(xticks=range(24))
plt.title('Зависимости количества поездок от часа в сутках для разных месяцев',fontsize = 14)
g3.set_xlabels('Номер часа в сутках',fontsize = 13)
g3.set_ylabels('Количесвто поездок',fontsize = 13);
# Построим график 4
for_fourth_graph = day_ride_by_hours.groupby(['day_name','hours_number']).sum().reset_index()[['day_name','hours_number','id']]
g4 = sns.relplot(data=for_fourth_graph, y='id', x = "hours_number",hue = 'day_name',kind="line",height=8, aspect=20/8)
g4.set(xticks=range(24))
plt.title('Зависимости количества поездок от часа в сутках для разных дней недели',fontsize = 14)
g4.set_xlabels('Номер часа в сутках',fontsize = 13)
g4.set_ylabels('Количесвто поездок',fontsize = 13);

# %% [markdown]
# **Вопрос**: Какие выводы можно сделать, основываясь на графиках выше? Выделяются ли какие-нибудь дни недели? Месяца? Время суток? С чем это связано?
#
# - График 1 (Зависимость количества поездок от часов в сутках):
#     - Меньше всего заказов в 5 часов утра (в это время люди предпочитают спать)
#     - Больше всего заказов в 6 часов вечера (Это может быть связано с окончание рабочего дня, т.е. заказы работа-дом или
#         вечером проходят светские мероприятия, такие как театры и т.п. На которые обычно приезжают на такси)
#     - С 8 утра до 3 дня количество заказов примерно одинаковое
# - График 2 (Зависимость количества поездок от дня недели):
#     - Самые популярные дни для заказа такси: Пятница, Суббота и Четверг (В пятницу и субботу все едут на мероприятия и по развлечениям)
#     - Самые непопулярные дни для заказа такси: Понедельник, Воскресение и Вторник
# - График 3 (Зависимости количества поездок от часа в сутках для разных месяцев):
#     - Здесь все как и в 1 графе, только мы можем заметь, что в Марте более активно заказывают такси в 8 часов утра
#     - В Июне меньше всего заказов в 16 часов
#     - В Марте больше всего заказов в 18 часов
# - График 4 (Зависимости количества поездок от часа в сутках для разных дней недели):
#     - Сильнее всего на этом графике выделяется Суббота и Воскресение в первой половине дня с 12 ночи до 5 утра в эти дни больше всего заказов
#     - В будни количество заказов между 5 и 8 часами утра набирается быстрее, нежели в выходные
#     - В воскресение меньше всего заказов после 5 вечера
#
# **Задание 4 (0.5 баллов)**. Разбейте выборку на обучающую и тестовую в отношении 7:3. По обучающей выборке нарисуйте график зависимости среднего логарифма времени поездки от дня недели. Затем сделайте то же самое, но для часа в сутках и дня в году.

# %%
# Разобъем данные на тестовую и тренеровочную выборки
(X_train,
 X_test,
 y_train,
 y_test) = train_test_split(frame.drop('log_trip_duration',axis = 1),
                                  frame['log_trip_duration'],test_size = 0.3,
                                  random_state = 42)

# %%
#Закодируем при помощи OHE признак и присоединим его к таблице
for_graph5 = X_train.merge(y_train,left_index=True,right_index=True)
# Добавляем новый признак: название дня недели
for_graph5['day_name'] = for_graph5['pickup_datetime'].dt.day_name()
# Добавляем новый признак: час в сутках
for_graph5['hours_number'] = for_graph5['pickup_datetime'].dt.hour
# Добавляем новый признак: день в году
for_graph5['dayofyear'] = for_graph5['pickup_datetime'].dt.dayofyear

# %%
# Построим график 5
for_fifth_graph = for_graph5.groupby('day_name').mean()['log_trip_duration'].reset_index()
g5 = sns.relplot(data=for_fifth_graph, y='log_trip_duration', x = "day_name",kind="line",height=8, aspect=20/8)
plt.title('Зависимости среднего логарифма времени поездки от дня недели',fontsize = 14)
g5.set_xlabels('День недели',fontsize = 13)
g5.set_ylabels('Логорифм длительности поездки',fontsize = 13);
# Построим график 6
for_sixth_graph = for_graph5.groupby('hours_number').mean()['log_trip_duration'].reset_index()
g6 = sns.relplot(data=for_sixth_graph, y='log_trip_duration', x = "hours_number",kind="line",height=8, aspect=20/8)
plt.title('Зависимости среднего логарифма времени поездки от часа в сутках',fontsize = 14)
g6.set(xticks=range(24))
g6.set_xlabels('Час в сутках ',fontsize = 13)
g6.set_ylabels('Логорифм длительности поездки',fontsize = 13);

# %%
for_seventh_graph = for_graph5.set_index('pickup_datetime').resample('1D').mean()['log_trip_duration'].reset_index()

# %%
# Построим график 7
g7 = sns.relplot(data=for_seventh_graph, y=for_seventh_graph['log_trip_duration'], x = for_seventh_graph["pickup_datetime"].astype('str'),kind="line",height=5, aspect=30/5)
plt.title('Зависимости среднего логарифма времени поездки от дня в году',fontsize = 14)
plt.xticks(rotation=90)
g7.set_xlabels('День в году ',fontsize = 13)
g7.set_ylabels('Логорифм длительности поездки',fontsize = 13);

# %% [markdown]
# **Вопрос**: Похожи ли графики зависимости таргета от дня недели и от часа в сутках на аналогичные графики для количества поездок? Почему? Что происходит со средним таргетом в те два аномальных периода, что мы видели выше? Почему так происходит? Наблюдаете ли вы какой-нибудь тренд на графике зависимости `log_trip_duration` от номера дня в году?

# %% [markdown]
# В графиках так же наблюдается сокращение длительности поездок в эти периоды. Это происходит в связи с резким палениям количества поездок, настолько резко и сильно, что это отражается на длительности поездки. На графике видно отчетливо видно 7-ми дневные тренды, которые можно раздельт еще на два тренда (рост и падения), которые длятся примерно одинаковое кол-во времени.

# %% [markdown]
# Добавьте следующие признаки на основе `pickup_datetime`:
# 1. День недели
# 2. Месяц
# 3. Час
# 4. Является ли период аномальным (два бинарных признака, соответствующие двум аномальным периодам)
# 5. Номер дня в году

# %%
# %%time
oulier_zone = pd.to_datetime(['2016-01-23','2016-01-24','2016-01-25','2016-01-26','2016-01-27','2016-05-29','2016-01-30'])

frame['outliers_zone'] = frame['pickup_datetime'].apply(lambda x: int(pd.to_datetime(x) in oulier_zone))
# Добавляем новый признак: название дня недели
frame['day_name'] = frame['pickup_datetime'].dt.day_name()
# Добавляем новый признак: час в сутках
frame['hours_number'] = frame['pickup_datetime'].dt.hour
# Добавляем новый признак: номер месяца (для следующего задания)
frame['month_name'] = frame['pickup_datetime'].dt.month_name()
# Добавляем новый признак: день в году
frame['dayofyear'] = frame['pickup_datetime'].dt.dayofyear
# Out:
# CPU times: user 18 s, sys: 174 ms, total: 18.2 s
# Wall time: 18.2 s

# %% [markdown]
# Итак, мы уже создали некоторое количество признаков.
#
# **Вопрос**: Какие из признаков стоит рассматривать как категориальные, а какие - как численные? Почему?
#
# Мне кажется, что так как у нас данные только за полгода, то смысла рассматривать день в году, как категориальный прищнак -нет, ибо возможно поподание данных на тесте из другой половины гола, что приведет к ошибке. А вот рассмотреть номер дня в недели и название месяца определенно стоит

# %% [markdown]
# **Задание 5 (0.75 баллов)**. Обучите `Ridge`-регрессию с параметрами по умолчанию, закодировав все категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`. Используйте только признаки, которые мы выделили в этой части задания.

# %%
# Скопируем исходный фрейм в временный
frame_ridge = frame.copy()
# Удалим ненужные признаки
frame_ridge = frame_ridge.drop(['vendor_id','pickup_datetime'],axis = 1)
# Делаем из id числовое значение и устанавливаем его как индекс
frame_ridge['id'] = frame_ridge['id'].apply(lambda x: int(x[2:]))
frame_ridge = frame_ridge.set_index('id')

# %%
cat_features_ridge = ['store_and_fwd_flag','day_name','month_name']

# %%
# Закодируем при помощи OHE признак и присоединим его к таблице
frame_ridge = frame_ridge.merge(pd.get_dummies(frame_ridge.loc[:,cat_features_ridge],drop_first=True),
                                left_index=True,
                                right_index=True)
# Удалим изначальный категориальный признак
frame_ridge = frame_ridge.drop(cat_features_ridge,axis = 1)

# %%
# Мне показалось странным добавлять признаки на разбитый по выборкам датасет,
# поэтому я добавил признаки на изначальный датасет, а теперь разделю его снова.
# Так как random_state не изменился, то и разбиение будет такое же 
(X_train_ridge,
 X_test_ridge,
 y_train_ridge,
 y_test_ridge) = train_test_split(frame_ridge.drop('log_trip_duration',axis = 1),
                                  frame_ridge['log_trip_duration'],test_size = 0.3,
                                  random_state = 42)

# %%
# Создадим пайплайн для модели
model_ridge = make_pipeline(StandardScaler(), Ridge())
model_ridge.fit(X_train_ridge,y_train_ridge)
preds_ridge = model_ridge.predict(X_test_ridge)

# %%
# Посчитаем метрику
rmsle_score_ridge = mean_squared_error(y_test_ridge,preds_ridge)
print('RMSLE на модели Ridge:', rmsle_score_ridge.round(4))
# Out:
# RMSLE на модели Ridge: 0.604

# %% [markdown]
# ## Часть 2. Изучаем координаты (3 балла)
# Мы уже очень хорошо изучили данные о времени начала поездки, давайте теперь посмотрим на информацию о координатах начала и конца поездки. Мы подготовили для вас функцию, которая на карте рисует точки начала или конца поездки. Примеры ее вызова вы найдете ниже. Обратите внимание, что в эту функцию мы передаем лишь небольшой кусочек данных, посколько иначе функция будет работать очень долго

# %%
def show_circles_on_map(data, latitude_column, longitude_column, color):
    """
    The function draws map with circles on it.
    The center of the map is the mean of coordinates passed in data.
    
    data: DataFrame that contains columns latitude_column and longitude_column
    latitude_column: string, the name of column for latitude coordinates
    longitude_column: string, the name of column for longitude coordinates
    color: string, the color of circles to be drawn
    """

    location = (data[latitude_column].mean(), data[longitude_column].mean())
    m = folium.Map(location=location)

    for _, row in data.iterrows():
        folium.Circle(
            radius=100,
            location=(row[latitude_column], row[longitude_column]),
            color=color,
            fill_color=color,
            fill=True
        ).add_to(m)

    return m

# %%
df = frame.copy()
show_circles_on_map(df.sample(1000), "pickup_latitude", "pickup_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
show_circles_on_map(df.sample(1000), "dropoff_latitude", "dropoff_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# **Вопрос**: Какие две точки выделяются на карте?

# %% [markdown]
# На карте выделяются 2 точки кроме Манхэттена - это аэропорт имени Джона Кеннеди и аэропорт LaGuardia

# %% [markdown]
# **Задание 6 (0.75 балл)**. Как мы все прекрасно помним, $t = s / v_{\text{ср}}$, поэтому очевидно, что самым сильным признаком будет расстояние, которое необходимо проехать. Мы не можем посчитать точное расстояние, которое необходимо преодолеть такси, но мы можем его оценить, посчитав кратчайшее расстояние между точками начала и конца поездки. Чтобы корректно посчитать расстояние между двумя точками на Земле, можно использовать функцию `haversine`. Также можно воспользоваться кодом с первого семинара. Посчитайте кратчайшее расстояние для объектов и запишите его в колонку `haversine`:

# %%
def get_distance_between_points(row):
    """
    Возвращает растояние между точками
    в киллометрах
    Входные параметры:
    row: Строка из датасета, где содержаться координаты 
    Выходные данные: 
    - Расстояние между точками в километрах
    """
    coord1,coord2 = ((row['pickup_latitude'],row['pickup_longitude']),
                     (row['dropoff_latitude'],row['dropoff_longitude']))
    return haversine(coord1, coord2)

# %%
# %%time
# Рассчитаем расстояние 
frame['haversine'] = frame.apply(get_distance_between_points,axis = 1)
# Out:
# CPU times: user 25.6 s, sys: 618 ms, total: 26.2 s
# Wall time: 26.3 s

# %% [markdown]
# Так как мы предсказываем логарифм времени поездки и хотим, чтобы наши признаки были линейно зависимы с этой целевой переменной, нам нужно логарифмировать расстояние: $\log t = \log s - \log{v_{\text{ср}}}$. Запишите логарифм `haversine` в отдельную колонку:

# %%
# Количество поездок с нулевым расстоянием
frame.query('haversine == 0').shape
# Out:
# (5897, 16)

# %%
# ЛОгарифмируем расстояние
frame['log_haversine'] = np.log1p(frame['haversine'])

# %% [markdown]
# Убедимся, что логарифм расстояния лучше коррелирует с нашим таргетом, чем просто расстояние:

# %%
# Построим матрицу корреляции
frame.loc[:,['log_haversine','haversine','log_trip_duration']].corr()
# Out:
#                    log_haversine  haversine  log_trip_duration
# log_haversine           1.000000   0.844501           0.749882
# haversine               0.844501   1.000000           0.573595
# log_trip_duration       0.749882   0.573595           1.000000

# %% [markdown]
# Как мы можем заметить, корреляция haversine с целевым признаком равна 0.573595, а log_haversine с таргетом 0.749882 это означает, что логарифм расстояния лучше коррелирует с нашим таргетом

# %% [markdown]
# **Задание 7 (0.75 балла)**. Давайте изучим среднюю скорость движения такси. Посчитайте среднюю скорость для каждого объекта обучающей выборки, разделив `haversine` на `trip_duration`, и нарисуйте гистограмму ее распределения

# %%
# Разобъем данные на тестовую и тренеровочную выборки, так как требуется
# скорость по обучающей выборке и счтать ее по всей будет некорректно
# Так как random_state не изменился, то и разбиение будет такое же, как и раньше
(X_train,
 X_test,
 y_train,
 y_test) = train_test_split(frame.drop('log_trip_duration',axis = 1),
                            frame['log_trip_duration'],test_size = 0.3,
                            random_state = 42)

# %%
# Скорость для каждого объекта обучающей выборки км/ч
train_speed = pd.Series(X_train['haversine']/((np.exp(y_train) - 1)/3600))

# %%
# Нарисуем гистограмму
plt.hist(train_speed)
plt.xlabel('Средняя скорость')
plt.ylabel('Количество объектов')
plt.title('Гистограмма распределения средней скорости');

# %% [markdown]
# Как можно видеть по гистограмме, для некоторых объектов у нас получились очень больше значения скоростей. Нарисуйте гистограмму по объектам, для которых значение скорости получилось разумным (например, можно не включать рассмотрение объекты, где скорость больше некоторой квантили):

# %%
# Посмотрим кол-во объектов со скоростью больше 120 км/ч
train_speed[train_speed > 120]
# Out:
# 39020       133.308058
# 1150761     126.605196
# 652631      272.761802
# 526984      125.793614
# 1013474    1756.560128
#               ...
# 1130403     349.788816
# 500725      424.861400
# 945772      166.043252
# 889973      226.670654
# 1306212     191.191359
# Length: 96, dtype: float64

# %% [markdown]
# В нашей выборке всего 96 поездок со скоростью больше 120 км/ч (приблизительная максимально разрешенная скорость в США), учитывая, что большая часть поездок проходит внутри города даже такие скорости там недоступны, но как мы могли видеть, есть поездка далеко загород. Поэтому, мне кажется, наилучшим решением будет отбросить все скорости выше 120 км/ч

# %%
# Гистограмма скорости после очистки
plt.hist(train_speed[train_speed <= 120], bins = 60)
plt.xlabel('Средняя скорость')
plt.ylabel('Количество объектов')
plt.title('Гистограмма распределения средней скорости');

# %% [markdown]
# Для каждой пары (день недели, час суток) посчитайте медиану скоростей. Нарисуйте с помощью `sns.heatmap` график, где по осям будут дни недели и часы, а в качестве значения функции - медиана скорости

# %%
# НАйдем для кажой пары день недели и час суток медиану скорост
train_speed = pd.DataFrame(train_speed).merge(X_train[['day_name','hours_number']],left_index=True,right_index=True)
train_speed.columns = ['speed','day_name','hours_number']

# %%
# Соберем данные в сводную таблицу
pivot_table_speed = train_speed.pivot_table(index= 'day_name',values = 'speed', columns = 'hours_number',aggfunc='median')

# %%
# Построем карту
sns.heatmap(pivot_table_speed)
plt.title('Карта зависисмотси скоторости от дня недели и часа',fontsize = 14)
# Out:
# Text(0.5, 1, 'Карта зависисмотси скоторости от дня недели и часа')

# %% [markdown]
# Не забудьте удалить колонку со значением скорости из данных!
#
# **Вопрос**: Почему значение скорости нельзя использовать во время обучения?

# %% [markdown]
# Как минимум по 2 причинам:
# - При помощи скорости и расстояния, модель очень быстро постановит время в дороге и ей больше ничего ничего не нужно будет
# - Мы не можем получить этот признак не зная времени в пути, а на тестовой выборке у нас не таргета

# %% [markdown]
# **Вопрос**: Посмотрите внимательно на график и скажите, в какие моменты времени скорость минимальна; максимальна.
#
# \-------------------
#
# **Ответ**:
#
# Самые темные участки на нашем графике характеризуют самое медленное движение, возможно это следствие пробок. Очень заметны два региона с такими значениями:
# 1. С 8 утра до 3 дня во вторник, среду и четверг
# 2. Тот же временной промежуток, но в пятницу
#
# Наоборот самую максимальную скорость развивают с 4 до 6 утра на протяжении всей недели
#
# ---------------------\
# Создайте признаки "поездка совершается в период пробок" и "поездка совершается в период свободных дорог" (естественно, они не должен зависеть от скорости!):

# %%
def is_traffic_jam(row):
    """
    Возвращает булево значение, которое означает
    попадает ли данная поездка в период пробок
    Входные параметры:
        row: Строка из датасета, где содержаться координаты 
    Выходные данные
        1: Если поездка происходит во время пробок
        0: Если поездка не происходит во время пробок
    """
    first_zone = (range(9,16),['Tuesday', 'Wednesday','Thursday'])
    second_zone = (range(9,13),['Friday'])
    if row['hours_number'] in first_zone[0] and row['day_name'] in first_zone[1]:
        return 1
    elif row['hours_number'] in second_zone[0] and row['day_name'] in second_zone[1]:
        return 1
    else:
        return 0

# %%
# Создадим признак означаюший тип дорожного трафика
frame['is_traffic_jam'] = frame.apply(is_traffic_jam,axis = 1)

# %% [markdown]
# **Задание 8 (0.25 балла)**. Как уже было замечено выше, на карте выделяются две точки вдали от Манхэттена. Для каждой из них добавьте в выборку два признака: началась ли поездка в ней и закончилась ли она в ней.

# %%
def is_airport(coord_of_squere,row, pickup = 1):
    """
    Сверят попадат ли поездка в зону аэропортов
    по переданным координатам
    """

    if pickup:
        flag_pickup = 0
        if (coord_of_squere[3][0] <= row['pickup_latitude'] <= coord_of_squere[0][0] 
            and coord_of_squere[3][1] <= row['pickup_longitude'] <= coord_of_squere[2][1]):
            flag_pickup = 1
        return flag_pickup
    else:
        flag_dropoff = 0
        if (coord_of_squere[3][0] <= row['dropoff_latitude'] <= coord_of_squere[0][0] 
            and coord_of_squere[3][1] <= row['dropoff_longitude'] <= coord_of_squere[2][1]):
            flag_dropoff = 1
        return flag_dropoff

# %%
# Обработаем точки и добавим новые признаки
first_point = (40.785551, -73.889003)
second_point = (40.785551, -73.852733)
third_point = (40.763418, -73.852733)
fourth_point = (40.763418, -73.889003)
all_points_LaGuardia = [first_point,second_point,third_point,fourth_point]
frame['is_LaGuardia_pickup'] = frame.apply(lambda row: is_airport(all_points_LaGuardia,row,1),axis = 1)
frame['is_LaGuardia_dropoff'] = frame.apply(lambda row: is_airport(all_points_LaGuardia,row,0),axis = 1)

# %%
# Обработаем точки и добавим новые признаки
first_point = (40.662536, -73.822522)
second_point = (40.662536, -73.747828)
third_point = (40.627019, -73.747828)
fourth_point = (40.627019, -73.822522)
all_points_Kennedy = [first_point,second_point,third_point,fourth_point]
frame['is_Kennedy_pickup'] = frame.apply(lambda row: is_airport(all_points_Kennedy,row,1),axis = 1)
frame['is_kennedy_dropoff'] = frame.apply(lambda row: is_airport(all_points_Kennedy,row,0),axis = 1)

# %% [markdown]
# Для каждого из созданных признаков нарисуйте "ящик с усами" (`sns.boxplot`) распределения логарифма времени поездки

# %%
sns.boxplot(x="is_LaGuardia_pickup", y="log_trip_duration", data=frame)
plt.title('Ящик с усами распределения логарифма времени поездки для is_LaGuardia_pickup',fontsize = 14)
plt.show()
sns.boxplot(x="is_LaGuardia_dropoff", y="log_trip_duration", data=frame)
plt.title('Ящик с усами распределения логарифма времени поездки для is_LaGuardia_dropoff',fontsize = 14)
plt.show()
sns.boxplot(x="is_Kennedy_pickup", y="log_trip_duration", data=frame)
plt.title('Ящик с усами распределения логарифма времени поездки для is_Kennedy_pickup',fontsize = 14)
plt.show()
sns.boxplot(x="is_kennedy_dropoff", y="log_trip_duration", data=frame)
plt.title('Ящик с усами распределения логарифма времени поездки для is_kennedy_dropoff',fontsize = 14)
plt.show()

# %% [markdown]
# **Вопрос**: судя по графикам, как вы думаете, хорошими ли получились эти признаки?

# %% [markdown]
# Достаточно сомнительными, в них определенно не хватает более точного разделения по областям

# %% [markdown]
# <img src="https://www.dropbox.com/s/xson9nukz5hba7c/map.png?raw=1" align="right" width="20%" style="margin-left: 20px; margin-bottom: 20px">
#
# **Задание 9 (1 балл)**. Сейчас мы почти что не используем сами значения координат. На это есть несколько причин: по отдельности рассматривать широту и долготу не имеет особого смысла, стоит рассматривать их вместе. Во-вторых, понятно, что зависимость между нашим таргетом и координатами не линейная. Чтобы как-то использовать координаты, можно прибегнуть к следующему трюку: обрамим область с наибольшим количеством поездок прямоугольником (как на рисунке). Разобьем этот прямоугольник на ячейки. Каждой точке сопоставим номер ее ячейки, а тем точкам, что не попали ни в одну из ячеек, сопоставим значение -1.
#
# Напишите трансформер, который сначала разбивает показанную на рисунке область на ячейки, а затем создает два признака: номер ячейки, в которой началась поездка, и номер ячейки, в которой закончилась поездка. Количество строк и столбцов выберите самостоятельно.
#
# Обратите внимание, что все вычисления должны быть векторизованными, трансформер не должен модифицировать передаваемую ему выборку inplace, а все необходимые статистики (если они вдруг нужны) нужно считать только по обучающей выборке в методе `fit`:

# %%
# %%time

from sklearn.base import BaseEstimator, TransformerMixin

class MapGridTransformer(BaseEstimator, TransformerMixin):
    
    def __init__(self,start_coods,n_split = 4):
        self.n_split = n_split
        self.start_coods = start_coods
        self.pickup_latitude = 'pickup_latitude'
        self.dropoff_latitude = 'dropoff_latitude'
        self.pickup_longitude = 'pickup_longitude'
        self.dropoff_longitude = 'dropoff_longitude'
    
    def fit(self, X = None, y = None ):
        self.coords_grid_map = self.split_map()
        return self
        
        
    def split_map(self):
        """
        Метод реализующий деление заданного квадрата на сетку
        """
        # Вычисляем длину одной стороны
        a_side = self.start_coods[0][0] - self.start_coods[3][0]
        b_side = self.start_coods[1][1] - self.start_coods[0][1]
        # Вычисляем длину одной ячейки
        step_by_a_side = a_side/self.n_split
        step_by_b_side = b_side/self.n_split
        coord_pairs = []
        # Задаем стартовую точку
        base_point = self.start_coods[0]
        coord_pairs = []
        # Перебираемся по сетке и запоминаем опорные точки
        # на основе которых потом будем проверять попадание новой точки в зону
        for mult_b in range(1,self.n_split+1):
            # Вычисляем координаты шага в ширину
            coord_pairs += [((base_point[0],base_point[1]+step_by_b_side),
                                (base_point[0]-step_by_a_side,base_point[1]))]
            for mult_a in range(2,self.n_split+1):
                # Итеририемся и ишем точки по высоте
                coord_pairs += [((coord_pairs[-1][1][0],coord_pairs[-1][0][1]),(coord_pairs[-1][1][0]-step_by_a_side,coord_pairs[-1][1][1]))]
            base_point = (base_point[0],base_point[1] + step_by_b_side)
        return  coord_pairs
        
    def num_of_area(self,row,lat,long):
        """
        Проверяем точки на вхождение в наши зоны
        
        """
        for num, coords_points in enumerate(self.coords_grid_map): 
            if ((coords_points[1][0] <= row[lat] <= coords_points[0][0]) and (coords_points[1][1] <= row[long] <= coords_points[0][1])):
                return num
        return -1
            
            
    def transform(self, X , y = None):
        
        self.frame = X.copy()
        self.frame['pickup_area'] = self.frame.loc[:,['pickup_longitude','pickup_latitude']].apply(lambda row: self.num_of_area(row,self.pickup_latitude,self.pickup_longitude),axis = 1)
        self.frame['dropoff_area'] = self.frame.apply(lambda row: self.num_of_area(row,self.dropoff_latitude,self.dropoff_longitude),axis = 1)
        return self.frame
# Out:
# CPU times: user 26 µs, sys: 1 µs, total: 27 µs
# Wall time: 28.8 µs

# %%
# Инициализируем трансформер
first_point = (40.832214, -74.028676)
second_point = (40.832214, -73.923550)
third_point = (40.700761, -73.923550)
fourth_point = (40.700761, -74.028676) 
coord_for_transform = [first_point,second_point,third_point,fourth_point]
train_transform = MapGridTransformer(coord_for_transform)

# %%
# Тренеруем трансформер 
train_transform.fit()
# Out:
# MapGridTransformer(start_coods=[(40.832214, -74.028676), (40.832214, -73.92355),
#                                 (40.700761, -73.92355),
#                                 (40.700761, -74.028676)])

# %%
# Подготавливаем выборку для трасформации
frame_transform = frame.copy()
frame_transform = frame_transform.drop(['vendor_id','pickup_datetime','haversine'],axis = 1)
frame_transform['id'] = frame_transform['id'].apply(lambda x: int(x[2:]))
frame_transform = frame_transform.set_index('id')
cat_features_transform = ['store_and_fwd_flag','day_name','month_name']
# Закодируем при помощи OHE признак и присоединим его к таблице
frame_transform = frame_transform.merge(pd.get_dummies(frame_transform.loc[:,cat_features_transform],drop_first=True),
                                left_index=True,
                                right_index=True)
# Удалим изначальный категориальный признак
frame_transform = frame_transform.drop(cat_features_transform,axis = 1)

# %%
# Делим выборку
(X_train_transform,
 X_test_transform,
 y_train_transform,
 y_test_transform) = train_test_split(frame_transform.drop('log_trip_duration',axis = 1),
                            frame_transform['log_trip_duration'],test_size = 0.3,
                            random_state = 42)

# %%
# %%time
X_train_transformed = train_transform.transform(X_train_transform)
X_test_transformed = train_transform.transform(X_test_transform)
# Out:
# CPU times: user 1min 27s, sys: 356 ms, total: 1min 27s
# Wall time: 1min 27s

# %% [markdown]
# **Задание 10 (0.25 балла)**. Обучите `Ridge`-регрессию со стандартными параметрами на признаках, которые мы выделили к текущему моменту. Категориальные признаки закодируйте через one-hot-кодирование, числовые признаки отмасштабируйте.

# %%
model_transformer = make_pipeline(StandardScaler(), Ridge())
model_transformer.fit(X_train_transformed,y_train_transform)
preds_trasform = model_transformer.predict(X_test_transformed)

# %%
# Посчитаем метрику
rmsle_score_transform = mean_squared_error(y_test_transform,preds_trasform)
print('RMSE на модели Ridge:', rmsle_score_transform.round(4))
# Out:
# RMSE на модели Ridge: 0.251

# %% [markdown]
# ## Часть 3. Изучаем оставшиеся признаки (1 балл)
#
# **Задание 11 (0.75 баллов)**. У нас осталось еще 3 признака, которые мы не исследовали: `vendor_id`, `passenger_count` и `store_and_fwd_flag`.
#
# **Вопрос**: Подумайте, почему каждый из этих признаков может быть потенциально полезным.
#
# `store_and_fwd_flag` отображает хранилась ли запись о поездке на устройстве до ее передачи провайдеру или пересылалась в режиме онлайн. В случае, когда запись не храниться, мы можем говорить о возможных ошибках в записи(это видно по кол-ву выбросов на графике под значением N)
#
# `passenger_count` поездки с большим кол-вом пассажиров длятся дольше
#
# `vendor_id`, как мы видим ниже, значение данного параметра не очень влияет на целевую переменную, но так же видно, что значения у 2 вендора ближе к усам
# Посчитайте, сколько есть уникальных значений у каждого из этих признаков:

# %%
print("Кол-во уникальных значений в passenger_count:",frame['passenger_count'].unique().shape[0])
print("Кол-во уникальных значений в vendor_id:",frame['vendor_id'].unique().shape[0])
print("Кол-во уникальных значений в store_and_fwd_flag:",frame['store_and_fwd_flag'].unique().shape[0])
# Out:
# Кол-во уникальных значений в passenger_count: 10
# Кол-во уникальных значений в vendor_id: 2
# Кол-во уникальных значений в store_and_fwd_flag: 2

# %% [markdown]
# Постройте "ящики с усами" распределений логарифма времени поездки в зависимости от значений каждого из признаков

# %%
frame.loc[:,['passenger_count','log_trip_duration']]
sns.boxplot(x='passenger_count', y="log_trip_duration", data=frame.loc[:,['passenger_count','log_trip_duration']])
plt.title('Распределений логарифма времени поездки в зависимости от значений passenger_count',fontsize = 14)
plt.show()

frame.loc[:,['passenger_count','log_trip_duration']]
sns.boxplot(x='vendor_id', y="log_trip_duration", data=frame.loc[:,['vendor_id','log_trip_duration']])
plt.title('Распределений логарифма времени поездки в зависимости от значений vendor_id',fontsize = 14)
plt.show()

frame.loc[:,['passenger_count','log_trip_duration']]
sns.boxplot(x='store_and_fwd_flag', y="log_trip_duration", data=frame.loc[:,['store_and_fwd_flag','log_trip_duration']])
plt.title('Распределений логарифма времени поездки в зависимости от значений store_and_fwd_flag',fontsize = 14)
plt.show()

# %% [markdown]
# Переведите признаки `vendor_id` и `store_and_fwd_flag` в значения $\{0;1\}$

# %%
frame['vendor_id'] = frame['vendor_id'].apply(lambda x: 1 if x == 1 else 0)
frame['store_and_fwd_flag'] = frame['store_and_fwd_flag'].apply(lambda x: 1 if x == 'N' else 0)

# %% [markdown]
# **Вопрос**: Основываясь на графиках выше, как вы думаете, будут ли эти признаки сильными?

# %% [markdown]
# Визуально, они достаточно слабо влияют на длину поездки

# %% [markdown]
# **Задание 12 (0.25 баллов)**. Проверьте свои предположения, обучив модель в том числе и на этих трех признаках. Обучайте `Ridge`-регрессию со стандартными параметрами. Категориальные признаки закодируйте one-hot-кодированием, а численные отмасштабируйте.

# %%
frame_features = frame.copy()
frame_features = frame_features.drop(['pickup_datetime','haversine'],axis = 1)
frame_features['id'] = frame_features['id'].apply(lambda x: int(x[2:]))
frame_features = frame_features.set_index('id')
cat_features_features = ['day_name','month_name']
# Закодируем при помощи OHE признак и присоединим его к таблице
frame_features = frame_features.merge(pd.get_dummies(frame_features.loc[:,cat_features_features],drop_first=True),
                                left_index=True,
                                right_index=True)
# Удалим изначальный категориальный признак
frame_features = frame_features.drop(cat_features_features,axis = 1)

# %%
(X_train_features,
 X_test_features,
 y_train_features,
 y_test_features) = train_test_split(frame_features.drop('log_trip_duration',axis = 1),
                            frame_features['log_trip_duration'],test_size = 0.3,
                            random_state = 42)

# %%
# %%time
X_train_feature = train_transform.transform(X_train_features)
X_test_feature = train_transform.transform(X_test_features)
# Out:
# CPU times: user 1min 28s, sys: 542 ms, total: 1min 28s
# Wall time: 1min 28s

# %%
model_features = make_pipeline(StandardScaler(), Ridge())
model_features.fit(X_train_feature,y_train_features)
preds_features = model_features.predict(X_test_feature)

# %%
# Посчитаем метрику
rmsle_score_features = mean_squared_error(y_test_features,preds_features)
print('RMSE на модели Ridge:', rmsle_score_features.round(4))
# Out:
# RMSE на модели Ridge: 0.2509

# %% [markdown]
# Если признаки не дали какого-то ощутимого улучшения метрики, их можно выбросить из данных.
#
# Ощутимо ничего не изменилось, так что удалим их

# %%
frame = frame.drop(['vendor_id','store_and_fwd_flag'],axis = 1)

# %% [markdown]
# ## Часть 4. Улучшаем модель (3 балла)

# %% [markdown]
# **Задание 13 (1 балл)**. В наших данных есть нетипичные объекты: с аномально маленьким времени поездки, с очень большим пройденным расстоянием или очень большими остатками регрессии. В этом задании предлагается исключить такие объекты из обучающей выборки. Для этого нарисуйте гистограммы распределения упомянутых выше величин, выберите объекты, которые можно назвать выбросами, и очистите обучающую выборку от них.
#
# Отметим, что хотя эти объекты и выглядят как выбросы, в тестовой выборке тоже скорее всего будут объекты с такими же странными значениями целевой переменной и/или признаков. Поэтому, возможно, чистка обучающей выборки приведёт к ухудшению качества на тесте. Тем не менее, всё равно лучше удалять выбросы из обучения, чтобы модель получалась более разумной и интерпретируемой.

# %%
frame['id'] = frame['id'].apply(lambda x: int(x[2:]))
frame = frame.set_index('id')

# %%
(X_train,
 X_test,
 y_train,
 y_test) = train_test_split(frame.drop('log_trip_duration',axis = 1),
                            frame['log_trip_duration'],test_size = 0.3,
                            random_state = 42)

# %%
def removing_outliers(column,frame, count = 0,total_outliers = 0, alpha = 1.5,max_iter = 3):
        """
        Метод удаления выбросов с помощью межквартильного размаха

        Параметры:
        - column: Имя столбца, где нужно найти выбросы
        - frame: Фрейм, где находится столбец для анализа
        - count: Количество рекурсивных циклов проверки 
        - total_outliers: Общая сумма выбросов, найденных за все циклы проверки
        - alpha: Коэфициент при вычислении интервала
        - max_iter: максимальное количество циклов функции

        Возвращет:
        - frame: Обработанный фрейм
        - leng: Количесвто выбросов на цикле
        - total_outliers: Общее количество выбросов
        """
        # Получим квантиль 25%
        q25=np.array(frame[column].describe(percentiles=[.25,.75]).loc['25%'])
        # Получим квантиль 75%
        q75=np.array(frame[column].describe(percentiles=[.25,.75]).loc['75%'])
        # Получим первую границу
        first_part=q25-alpha*(q75-q25)
        # Получим 2 границу
        second_part=q75+alpha*(q75-q25)
        # Получим все значения, удовлетворяющие промежутку
        prep_frame = frame[(frame[column] > first_part) & (frame[column] < second_part)]
        # Подсчет количества удаленных выбросов
        leng = frame.shape[0] - prep_frame.shape[0]
        # Увеление счетчика циклов
        count += 1
        # Заменим исходную таблицу обработанной
        frame = prep_frame.copy()
        # Удалим ненужную таблицу
        del prep_frame
        # Проверим условия выхода
        if leng > 0 and count < max_iter:
            frame,leng,total_outliers = removing_outliers(column,frame, count,total_outliers+leng)
        else:
            print('Количество строк, выбранных для удаления {}: {}. Количество итераций {}'.format(column,total_outliers,count),end = "\n\n")
        return frame,leng,total_outliers

# %%
sns.boxplot(y="haversine", data=X_train)
plt.title('Распределений расстояния поездки',fontsize = 14)
plt.ylabel('Расстояние поездки',fontsize = 14)
plt.show()

# %%
# Обработаем выбросы в haversine
X_train,_,_ = removing_outliers("haversine",X_train)
# Out:
# Количество строк, выбранных для удаления haversine: 139276. Количество итераций 3

# %%
sns.boxplot(y="haversine", data=X_train)
plt.title('Распределений расстояния поездки',fontsize = 14)
plt.ylabel('Расстояние поездки',fontsize = 14)
plt.show()

# %% [markdown]
# Пожалуй, так гораздо лучше

# %%
X_train_full = X_train.merge(y_train,left_index=True,right_index=True)

# %%
X_train_full['trip_duration'] = np.exp(X_train_full['log_trip_duration'])-1

# %%
sns.boxplot(y="trip_duration", data=X_train_full)
plt.title('Распределений длительности поездки',fontsize = 14)
plt.ylabel('Длительность поездки в секундах',fontsize = 14)
plt.show()

# %%
# Обработаем выбросы в haversine
X_train_full,_,_ = removing_outliers("trip_duration",X_train_full)
# Out:
# Количество строк, выбранных для удаления trip_duration: 32278. Количество итераций 3

# %%
sns.boxplot(y="trip_duration", data=X_train_full)
plt.title('Распределений длительности поездки',fontsize = 14)
plt.ylabel('Длительность поездки в секундах',fontsize = 14)
plt.show()

# %% [markdown]
# Отлично, теперь удалим trip_duration и haversine, потому что у нас есть их логарифмированные аналоги

# %%
X_train_full = X_train_full.drop(['trip_duration','haversine'],axis = 1)
X_train = X_train_full.drop('log_trip_duration',axis = 1)
y_train = X_train_full['log_trip_duration']
X_test = X_test.drop('haversine',axis = 1)

# %% [markdown]
# Сейчас у нас очень много категориальных признаков. В категориальных признаках могут содержаться редкие категории, обычно это плохо: модель сильно переобучается на таких примерах. Попробуйте объединить редкие категории в одну. Естественно, делать это нужно только для действительно редких категорий.

# %%
for i in X_train.loc[:,X_train.dtypes == np.dtype('object')].columns:
    print(X_train[i].value_counts(normalize=True))
# Out:
# Saturday     0.154809
# Friday       0.153341
# Thursday     0.147612
# Wednesday    0.142867
# Tuesday      0.139294
# Sunday       0.133501
# Monday       0.128576
# Name: day_name, dtype: float64
# March       0.177316
# April       0.171777
# May         0.166740
# February    0.166263
# January     0.160355
# June        0.157549
# Name: month_name, dtype: float64

# %% [markdown]
# Доли распределены примерно одинаково, поэтому нет какой то категории, которая была бы очень редкой

# %% [markdown]
# Обучите модель на очищенных данных и посчитайте качество на тестовой выборке.

# %% [markdown]
# **Задание 14 (1 балл)**. После OneHot-кодирования количество признаков в нашем датасете сильно возрастает. Посчитайте колиество признаков до и после кодирования категориальных признаков.

# %%
x_train_numbers_features_before = X_train.shape[1]

# %%
cat_features_X_test = X_test.loc[:,X_test.dtypes == np.dtype('object')].columns.tolist()
# Закодируем при помощи OHE признак и присоединим его к таблице
X_test = X_test.merge(pd.get_dummies(X_test.loc[:,cat_features_X_test],drop_first=True),
                                left_index=True,
                                right_index=True)
# Удалим изначальный категориальный признак
X_test = X_test.drop(cat_features_X_test,axis = 1)

# %%
cat_features_X_train = X_train.loc[:,X_train.dtypes == np.dtype('object')].columns.tolist()
# Закодируем при помощи OHE признак и присоединим его к таблице
X_train = X_train.merge(pd.get_dummies(X_train.loc[:,cat_features_X_train],drop_first=True),
                                left_index=True,
                                right_index=True)
# Удалим изначальный категориальный признак
X_train = X_train.drop(cat_features_X_train,axis = 1)

# %%
# %%time
X_train = train_transform.transform(X_train)
X_test = train_transform.transform(X_test)
# Out:
# CPU times: user 1min 15s, sys: 584 ms, total: 1min 15s
# Wall time: 1min 15s

# %%
print('Разница между кол-вом признаков до и после:', X_train.shape[1] - x_train_numbers_features_before)
# Out:
# Разница между кол-вом признаков до и после: 11

# %%
X_train = X_train.drop('pickup_datetime',axis = 1)
X_test = X_test.drop('pickup_datetime',axis = 1)

# %% [markdown]
# Попробуйте обучить не `Ridge`-, а `Lasso`-регрессию. Какой метод лучше?

# %%
model_task14_ridge = Pipeline(steps=[('stand',StandardScaler()), ('ridge',Ridge())])
model_task14_ridge.fit(X_train,y_train)
preds_task14_ridge  = model_task14_ridge.predict(X_test)

# %%
# Посчитаем метрику
rmsle_score_task14_ridge = mean_squared_error(y_test,preds_task14_ridge)
print('RMSE на модели Ridge:', rmsle_score_task14_ridge)
# Out:
# RMSE на модели Ridge: 0.2657783047709744

# %%
model_task14_lasso =  Pipeline(steps=[('stand',StandardScaler()), ('lasso',Lasso())])
model_task14_lasso.fit(X_train,y_train)
preds_task14_lasso  = model_task14_lasso.predict(X_test)

# %%
# Посчитаем метрику
rmsle_score_task14_lasso = mean_squared_error(y_test,preds_task14_lasso)
print('RMSE на модели Lasso:', rmsle_score_task14_lasso.round(4))
# Out:
# RMSE на модели Lasso: 0.6848

# %% [markdown]
# Ridge справляется лучше

# %% [markdown]
# Разбейте обучающую выборку на обучающую и валидационную в отношении 8:2. По валидационной выборке подберите оптимальные значения параметра регуляризации (по логарифмической сетке) для `Ridge` и `Lasso`, на тестовой выборке измерьте качество лучшей полученной модели.

# %%
(X_train_valid,
 X_valid,
 y_train_valid,
 y_valid) = train_test_split(X_train,
                            y_train,test_size = 0.2,
                            random_state = 42)

# %%
parameters_ridge = {'ridge__alpha':np.linspace(1e-2,10)}
parameters_lasso = {'lasso__alpha':np.linspace(1e-10,1)}

# %%
# %%time
search_ridge = GridSearchCV(model_task14_ridge, parameters_ridge , n_jobs=-1)
search_ridge.fit(X_train_valid,y_train_valid)
# Out:
# CPU times: user 3.02 s, sys: 3.57 s, total: 6.59 s
# Wall time: 1min 39s
# GridSearchCV(estimator=Pipeline(steps=[('stand', StandardScaler()),
#                                        ('ridge', Ridge())]),
#              n_jobs=-1,
#              param_grid={'ridge__alpha': array([ 0.01      ,  0.21387755,  0.4177551 ,  0.62163265,  0.8255102 ,
#         1.02938776,  1.23326531,  1.43714286,  1.64102041,  1.84489796,
#         2.04877551,  2.25265306,  2.45653061,  2.66040816,  2.86428571,
#         3.06816327,  3.27204082,  3.47591837,  3.67979592,  3.88367347,
#         4.08755102,  4.29142857,  4.49530612,  4.69918367,  4.90306122,
#         5.10693878,  5.31081633,  5.51469388,  5.71857143,  5.92244898,
#         6.12632653,  6.33020408,  6.53408163,  6.73795918,  6.94183673,
#         7.14571429,  7.34959184,  7.55346939,  7.75734694,  7.96122449,
#         8.16510204,  8.36897959,  8.57285714,  8.77673469,  8.98061224,
# ...

# %%
search_ridge.best_params_
# Out:
# {'ridge__alpha': 10.0}

# %%
preds_search_ridge = search_ridge.predict(X_valid)
rmsle_score_search_ridge = mean_squared_error(y_valid,preds_search_ridge)
print('RMSE на модели Ridge:', rmsle_score_search_ridge)
# Out:
# RMSE на модели Ridge: 0.20880754794428383

# %%
# %%time
search_lasso = GridSearchCV(model_task14_lasso, parameters_lasso , n_jobs=-1)
search_lasso.fit(X_train_valid,y_train_valid)
# Out:
# CPU times: user 1min 59s, sys: 10.6 s, total: 2min 9s
# Wall time: 4min 55s
# GridSearchCV(estimator=Pipeline(steps=[('stand', StandardScaler()),
#                                        ('lasso', Lasso())]),
#              n_jobs=-1,
#              param_grid={'lasso__alpha': array([1.00000000e-10, 2.04081634e-02, 4.08163266e-02, 6.12244899e-02,
#        8.16326532e-02, 1.02040816e-01, 1.22448980e-01, 1.42857143e-01,
#        1.63265306e-01, 1.83673469e-01, 2.04081633e-01, 2.24489796e-01,
#        2.44897959e-01, 2.65306123e-01, 2.85714286...
#        4.89795918e-01, 5.10204082e-01, 5.30612245e-01, 5.51020408e-01,
#        5.71428571e-01, 5.91836735e-01, 6.12244898e-01, 6.32653061e-01,
#        6.53061225e-01, 6.73469388e-01, 6.93877551e-01, 7.14285714e-01,
#        7.34693878e-01, 7.55102041e-01, 7.75510204e-01, 7.95918367e-01,
#        8.16326531e-01, 8.36734694e-01, 8.57142857e-01, 8.77551020e-01,
#        8.97959184e-01, 9.18367347e-01, 9.38775510e-01, 9.59183673e-01,
# ...

# %%
preds_search_lasso = search_lasso.predict(X_valid)
rmsle_score_search_lasso = mean_squared_error(y_valid,preds_search_lasso)
print('RMSE на модели Lasso:', rmsle_score_search_lasso)
# Out:
# RMSE на модели Lasso: 0.20880754772228116

# %% [markdown]
# Для каждого перебранного `alpha` для Lasso посчитайте количество нулевых весов в модели и нарисуйте график зависимости его от `alpha`. Как сильно придётся потерять в качестве, если мы хотим с помощью Lasso избавиться хотя бы от половины признаков?

# %%
stats = pd.DataFrame(columns = ['alpha','count_zero'])

# %%
from tqdm import tqdm

# %%
for alpha in tqdm(np.linspace(1e-10,0.6,num=100)):
    model_task14_lasso_br =  Pipeline(steps=[('stand',StandardScaler()), ('lasso',Lasso(alpha=alpha))])
    model_task14_lasso_br.fit(X_train_valid,y_train_valid)
    count_zero = sum(model_task14_lasso_br['lasso'].coef_ == 0)
    stats = stats.append({'alpha': alpha,'count_zero':count_zero}, ignore_index=True)
# Out:
# 100%|██████████| 100/100 [01:37<00:00,  1.03it/s]

# %%
sns.lineplot(data = stats,x = 'alpha',y = 'count_zero')
plt.title('Зависимости количество нулевых весов в модели от alpha',fontsize = 14)
plt.ylabel('Кол-во нулей в модели',fontsize = 14)
plt.xlabel('Alpha',fontsize = 14)
plt.show()

# %% [markdown]
# <img src="https://www.dropbox.com/s/wp4jj0599np17lh/map_direction.png?raw=1" width="20%" align="right" style="margin-left: 20px">
#
# **Задание 15 (1 балл)**. Часто бывает полезным использовать взаимодействия признаков (feature interactions), то есть строить новые признаки на основе уже существующих. Выше мы разбили карту Манхэттена на ячейки и придумали признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка".
#
# Давайте попробуем сделать следующее: посчитаем, сколько раз встречается каждая возможная пара этих признаков в нашем датасете и выберем 100 самых частых пар. Закодируем поездки с этими частыми парами как категориальный признак, остальным объектам припишем -1. Получается, что мы закодировали, откуда и куда должно было ехать такси.
#
# Также можете придумать ещё какой-нибудь способ сделать признаки про маршрут. Если эти признаки будут давать хороший прирост в качестве, то за это могут быть даны дополнительные бонусные баллы.
#
# **Вопрос**: Почему такой признак потенциально полезный? Почему линейная модель не может самостоятельно "вытащить" эту информацию, ведь у нее в распоряжении есть признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка"?
#
# **Ответ**
# - Тем самым мы как бы группируем поездки в большие множества, которые могут содержать необходимые особенности
# - Обычная линейная модель, все же рассматривает признаки как самостоятельные элементы, а тут мы агрегируем и показываем, что между ними есть достаточно очевидная связь

# %%
# Подготавливаем данные 
from_to_features = X_train.groupby(['pickup_area','dropoff_area']).count().iloc[:,0].reset_index()
from_to_features.columns = ['pickup_area','dropoff_area','passenger_count']
from_to_features = from_to_features.sort_values(by = 'passenger_count',ascending=False)[:100]
from_to_features['position'] = np.array(range(100,0,-1))

# %%
# Удалим ненужный столбец: так как все данные из него мы уже перенесли
from_to_features = from_to_features.drop('passenger_count',axis = 1)

# %%
def get_pair_cat(row):
    """
    В зависимости от пары зона начала/конца поездки подберем дополнительный признак
    """
    pick = row['pickup_area']
    drop = row['dropoff_area']
    pos = from_to_features[(from_to_features['pickup_area'] == pick) & (from_to_features['dropoff_area'] == drop)]['position']
    if  pos.empty:
        return -1
    else:
        return pos.values[0]

# %%
# %%time
X_train['position'] = X_train.loc[:,['pickup_area','dropoff_area']].apply(get_pair_cat,axis = 1)
# Out:
# CPU times: user 4min 58s, sys: 2.4 s, total: 5min
# Wall time: 4min 59s

# %%
# %%time
X_test['position'] = X_test.loc[:,['pickup_area','dropoff_area']].apply(get_pair_cat,axis = 1)
# Out:
# CPU times: user 2min 40s, sys: 1.07 s, total: 2min 41s
# Wall time: 2min 41s

# %% [markdown]
# Заново обучите модель (`Ridge`, если она дала более высокое качество в предыдущих экспериментах, и `Lasso` иначе) на новых даннных и посчитайте качество на тестовой выборке

# %%
model_task15_lasso =  Pipeline(steps=[('stand',StandardScaler()), ('lasso',Lasso(alpha = 1e-6))])
model_task15_lasso.fit(X_train,y_train)
preds_task15_lasso  = model_task15_lasso.predict(X_test)

# %%
# Посчитаем метрику
rmsle_score_task15_lasso = mean_squared_error(y_test,preds_task15_lasso)
print('RMSE на модели Lasso:', rmsle_score_task15_lasso.round(4))
# Out:
# RMSE на модели Lasso: 0.2558

# %% [markdown]
# **Задание 16 (бонус, 1 балл)**. Где, как не для нашей задачи, считать манхэттенское расстояние?
#
# **Вопрос**: Найдите, что такое манхэттенское расстояние и почему оно так называется. Как оно нам может помочь?
#
# Введите систему координат на нашей карте так, чтобы оси были параллельны улицам Манхэттена, и добавьте сначала в данные признак "манхэттенское расстояние между пунктом отправления и пунктом назначения", а затем и логарифм этого признака. Посчитайте корреляцию между вашим новыми признаком и таргетом; между `log_haversine` и таргетом. В каком случае корреляция больше?
#
# Нарисуйте карту, где покажете выбранные оси. Чтобы мы могли проверить вашу работу, просьба сделать скрин этой карты и приложить картинку (если мы откроем ваш ноутбук, виджеты отображаться не будут).

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# Заново обучите модель на новых даннных и посчитайте качество на тестовой выборке. Стало ли лучше? Объясните полученный результат.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **Задание 17 (бонус, 2 балла)**. Реализуйте трансформер, который строит разбиение карты по шестигранной решётке с помощью библиотеки [H3](https://github.com/uber/h3-py) и вычисляет признаки на основе такого разбиения.
#
# Признаки могут быть самые разные: расстояние между точкой старта и финиша, посчитанное в количестве шестиугольников; статистика по числу поездок и по их продолжительности в соседних шестиугольниках.
#
# Важно: производительность библиотеки существенно зависит от количества шестиугольников на карте (определяется параметром resolution). Подберите такое разрешение, при котором ваш код будет работать за приемлемое время.
#
# При построении признаков старайтесь не допустить утечки целевой переменной (подробнее про это можно почитать в материалах 1-го семинара) — в противном случае хорошего качества на тестовой выборке достичь не получится.
#
# Измерьте качество после добавления новых признаков. За улучшение функционала ошибки на каждые 0.005 на тестовой выборке будет даваться 0.5 бонусных балла. Можно получить до 2 бонусных баллов за это задание.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого ДЗ.

# %% [markdown]
# Когда я писал трансформер и пытался проверить на все ли теоретические вопросы я ответил:
# <img src = 'https://media.giphy.com/media/4JVTF9zR9BicshFAb7/giphy.gif'>
